# %%
#Importing needed libraries 
import pandas as pd
import requests
import config

# %%
#Defining Parameters 
City = "Provo"
State = "Utah"
Begin_Time = "/2022-01-01"
End_Time = "/2022-10-16"

#Accessing hidden api key
API_Key = config.api_key


#Combining it all into the api url 
url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/" + City + "%2C%20" + State + Begin_Time + End_Time + "?unitGroup=us&elements=datetime%2Ctempmax%2Ctempmin%2Ctemp%2Cfeelslikemax%2Cfeelslikemin%2Cfeelslike%2Chumidity%2Cprecip%2Cprecipprob%2Cwindspeed%2Ccloudcover%2Csolarradiation%2Csolarenergy%2Cuvindex%2Csunrise%2Csunset%2Cconditions&key=" + API_Key + "&contentType=json"

# %%
#Requesting the url 
r = requests.get(url)

#Status of the request 
print(r.status_code)

#Creating the json file into a pandas data frame 
df = pd.DataFrame(r.json()['days'])
# Out:
# 200

# %%
#import csv

#Creating the dataframe into a csv 

#df.to_csv(r'/Users/drew/OneDrive_BYU/STAT386/Provo_Weather-/weather.csv')
# Out:
#        datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0    2022-01-01     23.0      9.0  18.0          20.0          -1.0
# 1    2022-01-02     28.1      5.0  13.4          26.9          -9.9
# 2    2022-01-03     34.0     11.1  23.2          34.0           1.5
# 3    2022-01-04     40.9     25.1  32.3          36.6          19.3
# 4    2022-01-05     39.8     29.1  35.5          38.0          29.1
# ..          ...      ...      ...   ...           ...           ...
# 284  2022-10-12     72.0     40.0  55.8          72.0          37.9
# 285  2022-10-13     70.1     39.9  54.3          70.1          39.9
# 286  2022-10-14     70.1     39.0  54.0          70.1          37.8
# 287  2022-10-15     71.2     37.9  54.4          71.2          34.4
# 288  2022-10-16     72.0     40.9  57.1          72.0          36.5
#
#      feelslike  humidity  precip  precipprob  windspeed  cloudcover  \
# 0          7.5      68.0    0.00         0.0       20.7        44.8
# 1          8.4      70.5    0.00         0.0       10.3         0.2
# 2         18.2      71.3    0.00         0.0       10.3        10.2
# 3         27.6      67.1    0.00         0.0       14.9        60.4
# 4         32.1      84.6    0.06       100.0        9.1       100.0
# ..         ...       ...     ...         ...        ...         ...
# 284       55.1      45.3    0.00         0.0       16.0         0.0
# 285       53.7      51.7    0.00         0.0        9.1         0.0
# 286       53.3      45.8    0.00         0.0        8.0         0.0
# 287       53.6      41.1    0.00         0.0       12.5        14.3
# 288       56.2      43.4    0.00         0.0       22.4         0.0
#
#      solarradiation  solarenergy  uvindex   sunrise    sunset  \
# 0              46.0          3.9      2.0  07:49:24  17:11:33
# 1              69.4          6.1      3.0  07:49:30  17:12:25
# 2              75.7          6.5      4.0  07:49:33  17:13:17
# 3              36.6          3.0      2.0  07:49:34  17:14:11
# 4              16.8          1.3      1.0  07:49:33  17:15:07
# ..              ...          ...      ...       ...       ...
# 284           777.2         67.3     10.0  07:34:20  18:51:17
# 285           776.5         67.3     10.0  07:35:23  18:49:45
# 286           777.5         67.4     10.0  07:36:26  18:48:14
# 287           776.9         67.1     10.0  07:37:29  18:46:43
# 288           780.5         67.5     10.0  07:38:33  18:45:14
#
#            conditions                                              hours
# 0    Partially cloudy  [{'datetime': '00:00:00', 'temp': 21.8, 'feels...
# 1               Clear  [{'datetime': '00:00:00', 'temp': 9.0, 'feelsl...
# 2               Clear  [{'datetime': '00:00:00', 'temp': 12.0, 'feels...
# 3    Partially cloudy  [{'datetime': '00:00:00', 'temp': 30.9, 'feels...
# 4      Rain, Overcast  [{'datetime': '00:00:00', 'temp': 29.1, 'feels...
# ..                ...                                                ...
# 284             Clear  [{'datetime': '00:00:00', 'temp': 52.1, 'feels...
# 285             Clear  [{'datetime': '00:00:00', 'temp': 48.9, 'feels...
# 286             Clear  [{'datetime': '00:00:00', 'temp': 48.9, 'feels...
# 287             Clear  [{'datetime': '00:00:00', 'temp': 49.9, 'feels...
# 288             Clear  [{'datetime': '00:00:00', 'temp': 49.7, 'feels...
#
# [289 rows x 19 columns]
